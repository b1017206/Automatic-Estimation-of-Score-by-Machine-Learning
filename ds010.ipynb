# %% [markdown]
# # データ整形(1819年度CDEFJKLクラス)

# %%
import pandas as pd
#最大表示行数の指定（ここでは400行を指定）
pd.set_option('display.max_rows', 400)

# %%
#元データ（演習課題）
df = pd.read_csv('all1819_ka.csv')
df
# Out:
#        userid                            name  submitnumber  score  answertime
# 0      182233                課題1-1 関数の実装 (木曜)             8   10.0       10213
# 1      182233           課題1-2 関数の実装と動作確認 (木曜)             1    3.6       10733
# 2      182233        課題10-1 Personクラスの導入 (木曜)             1    0.0      199898
# 3      182233     課題2-1: フローチャートとロジックの実装 (木曜)            11    3.0        9547
# 4      182233  課題3-1 都市のデータを格納するクラス（その１） (木曜)             2   10.0        8540
# ...       ...                             ...           ...    ...         ...
# 14381  193734      課題9-1 簡易テキストマイニング（その１）(木曜)             6   10.0        6671
# 14382  193734      課題9-2 簡易テキストマイニング（その２）(木曜)             1   10.0        9444
# 14383  193734             課題Python (IDF) (木曜)             1   10.0        6623
# 14384  193734              課題Python (TF) (木曜)             3   10.0        5033
# 14385  193734          課題Python (TF-IDF) (木曜)             3   10.0        8071
#
# ...

# %%
#元データ（教科書クイズ）
df2 = pd.read_csv('all1819_kyo.csv')
df2
# Out:
#        Unnamed: 0               name  userid  submitnumber  score
# 0               0  教科書の内容の確認クイズ (8章)  182233             1    3.0
# 1               1  教科書の内容の確認クイズ (8章)  182324             1    3.0
# 2               2  教科書の内容の確認クイズ (8章)  182669             1    3.0
# 3               3  教科書の内容の確認クイズ (8章)  182771             1    3.0
# 4               4  教科書の内容の確認クイズ (8章)  182787             1    3.0
# ...           ...                ...     ...           ...    ...
# 11602        7805  教科書の内容の確認クイズ (7章)  193729             2    5.0
# 11603        7806  教科書の内容の確認クイズ (7章)  193730             1    5.0
# 11604        7807  教科書の内容の確認クイズ (7章)  193731             1    5.0
# 11605        7808  教科書の内容の確認クイズ (7章)  193733             1    5.0
# 11606        7809  教科書の内容の確認クイズ (7章)  193734             1    5.0
#
# [11607 rows x 5 columns]

# %%
df2_2 = df2.sort_values(['userid','name'])
df2_2
# Out:
#       Unnamed: 0                   name  userid  submitnumber     score
# 3565        3565  教科書の内容の確認クイズ (1,2,3章)  182233             1   8.00000
# 801          801     教科書の内容の確認クイズ (10章)  182233             1   8.00000
# 1067        1067     教科書の内容の確認クイズ (11章)  182233             1  10.00000
# 2089        2089     教科書の内容の確認クイズ (12章)  182233             1  12.00000
# 2072        2072     教科書の内容の確認クイズ (13章)  182233             1   8.00000
# ...          ...                    ...     ...           ...       ...
# 8059        4262      教科書の内容の確認クイズ (8章)  193734             1   3.00000
# 8326        4529      教科書の内容の確認クイズ (9章)  193734             1   2.57143
# 8327        4530      教科書の内容の確認クイズ (9章)  193734             2   2.57143
# 8328        4531      教科書の内容の確認クイズ (9章)  193734             3   3.00000
# 8329        4532      教科書の内容の確認クイズ (9章)  193734             4   3.00000
#
# [11607 rows x 5 columns]

# %%
#answertime（回答時間）除外
df_3=df[["userid","name","submitnumber","score"]]
df_3.head(50)
# Out:
#     userid                                  name  submitnumber  score
# 0   182233                      課題1-1 関数の実装 (木曜)             8  10.00
# 1   182233                 課題1-2 関数の実装と動作確認 (木曜)             1   3.60
# 2   182233              課題10-1 Personクラスの導入 (木曜)             1   0.00
# 3   182233           課題2-1: フローチャートとロジックの実装 (木曜)            11   3.00
# 4   182233        課題3-1 都市のデータを格納するクラス（その１） (木曜)             2  10.00
# 5   182233        課題3-2 都市のデータを格納するクラス（その２） (木曜)             3   0.72
# 6   182233              課題5-1 Countryクラスの導入 (木曜)             9   3.42
# 7   182233                  課題5-2 ランキング用ソート (木曜)             3   3.42
# 8   182233                    課題6-1 メソッドの使用 (木曜)             2   8.00
# 9   182233             課題6-2 Comparableへの対応 (木曜)             1   4.80
# 10  182233           課題7-1 クラスの継承(PointCard)（木曜）             3  10.00
# 11  182233                   課題7-2 簡易データベース1（木曜）             1  10.00
# ...

# %%
#演習課題の種類（個数）をリスト化
kadai = df_3['name'].unique().tolist()
kadai
# Out:
# ['課題1-1 関数の実装 (木曜)',
#  '課題1-2 関数の実装と動作確認 (木曜)',
#  '課題10-1 Personクラスの導入 (木曜)',
#  '課題2-1: フローチャートとロジックの実装 (木曜)',
#  '課題3-1 都市のデータを格納するクラス（その１） (木曜)',
#  '課題3-2 都市のデータを格納するクラス（その２） (木曜)',
#  '課題5-1 Countryクラスの導入 (木曜)',
#  '課題5-2 ランキング用ソート (木曜)',
#  '課題6-1 メソッドの使用 (木曜)',
#  '課題6-2 Comparableへの対応 (木曜)',
#  '課題7-1 クラスの継承(PointCard)（木曜）',
#  '課題7-2 簡易データベース1（木曜）',
#  '課題7-3 簡易データベース2（木曜）',
#  '課題（Python言語演習）：奇数の最大値・最小値（木曜）',
#  '課題（Python言語演習）：距離の総和（木曜）',
#  '課題（Python言語演習）：２つのリストからの約数探し（木曜）',
#  '課題10-2 簡易レコメンデーションの改良 (木曜)',
#  '課題2-2：モンテカルロ法でπの近似値を計算 (木曜)',
#  '課題4-1 都市の人口流出入シミュレーション（その１）（木曜）',
#  '課題4-2 都市の人口流出入シミュレーション（その２）（木曜）',
#  '課題4-3 都市の人口流出入シミュレーション（その３）(木曜)',
#  '課題8-1 自治体のオープンデータから統計情報を求める（その１）(木曜)',
#  '課題8-2 自治体のオープンデータから統計情報を求める（その２）(木曜)',
#  '課題9-1 簡易テキストマイニング（その１）(木曜)',
#  '課題9-2 簡易テキストマイニング（その２）(木曜)',
#  '課題1-1 関数の実装 (火曜)',
#  '課題1-2 関数の実装と動作確認 (火曜)',
#  '課題10-1 Personクラスの導入 (火曜)',
#  '課題10-2 簡易レコメンデーションの改良 (火曜)',
#  '課題2-1: フローチャートとロジックの実装 (火曜)',
# ...

# %%
#教科書クイズの種類（個数）をリスト化
kyoukasyo = df2_2['name'].unique().tolist()
kyoukasyo
# Out:
# ['教科書の内容の確認クイズ (1,2,3章)',
#  '教科書の内容の確認クイズ (10章)',
#  '教科書の内容の確認クイズ (11章)',
#  '教科書の内容の確認クイズ (12章)',
#  '教科書の内容の確認クイズ (13章)',
#  '教科書の内容の確認クイズ (4章)',
#  '教科書の内容の確認クイズ (5章)',
#  '教科書の内容の確認クイズ (6章) - 前回出題漏れのため再掲載',
#  '教科書の内容の確認クイズ (7章)',
#  '教科書の内容の確認クイズ (8章)',
#  '教科書の内容の確認クイズ (9章)',
#  '教科書の内容の確認クイズ (6章)']

# %%
#授業第３回目まで
kadai123=['課題1-1 関数の実装 (木曜)',
          '課題1-2 関数の実装と動作確認 (木曜)',
          '課題1-1 関数の実装 (火曜)',
          '課題1-2 関数の実装と動作確認 (火曜)',
          '課題1-2 Eclipseデバッガを使う (木曜)',
          '課題1-3 関数の実装と動作確認 (木曜)', 
          '課題1-2 Eclipseデバッガを使う (火曜)',
          '課題1-3 関数の実装と動作確認 (火曜)',
          '課題2-1: フローチャートとロジックの実装 (木曜)',
          '課題3-1 都市のデータを格納するクラス（その１） (木曜)',
          '課題3-2 都市のデータを格納するクラス（その２） (木曜)',
          '課題2-2：モンテカルロ法でπの近似値を計算 (木曜)',
          '課題2-1: フローチャートとロジックの実装 (火曜)',
          '課題2-2：モンテカルロ法でπの近似値を計算 (火曜)',
          '課題3-1 都市のデータを格納するクラス（その１） (火曜)',
          '課題3-2 都市のデータを格納するクラス（その２） (火曜)',
          '課題3-1 コンストラクタの作成（木曜）',
          '課題3-2 インスタンスメソッドの作成（木曜）',
          '課題3-3 クラスメソッドの作成（木曜）',
          '課題3-1 コンストラクタの作成（火曜）',
          '課題3-2 インスタンスメソッドの作成（火曜）',
          '課題3-3 クラスメソッドの作成（火曜）']
kyoukasyo123=['教科書の内容の確認クイズ (1,2,3章)',
              '教科書の内容の確認クイズ (4章)',
              '教科書の内容の確認クイズ (5章)',
              '教科書の内容の確認クイズ (7章)']
#授業第４回目まで
kadai4=['課題1-1 関数の実装 (木曜)',
        '課題1-2 関数の実装と動作確認 (木曜)',
        '課題1-1 関数の実装 (火曜)',
        '課題1-2 関数の実装と動作確認 (火曜)',
        '課題1-2 Eclipseデバッガを使う (木曜)',
        '課題1-3 関数の実装と動作確認 (木曜)', 
        '課題1-2 Eclipseデバッガを使う (火曜)',
        '課題1-3 関数の実装と動作確認 (火曜)',
        '課題2-1: フローチャートとロジックの実装 (木曜)',
        '課題3-1 都市のデータを格納するクラス（その１） (木曜)',
        '課題3-2 都市のデータを格納するクラス（その２） (木曜)',
        '課題2-2：モンテカルロ法でπの近似値を計算 (木曜)',
        '課題2-1: フローチャートとロジックの実装 (火曜)',
        '課題2-2：モンテカルロ法でπの近似値を計算 (火曜)',
        '課題3-1 都市のデータを格納するクラス（その１） (火曜)',
        '課題3-2 都市のデータを格納するクラス（その２） (火曜)',
        '課題3-1 コンストラクタの作成（木曜）',
        '課題3-2 インスタンスメソッドの作成（木曜）',
        '課題3-3 クラスメソッドの作成（木曜）',
        '課題3-1 コンストラクタの作成（火曜）',
        '課題3-2 インスタンスメソッドの作成（火曜）',
        '課題3-3 クラスメソッドの作成（火曜）',
        '課題4-1 都市の人口流出入シミュレーション（その１）（木曜）',
        '課題4-2 都市の人口流出入シミュレーション（その２）（木曜）',
        '課題4-3 都市の人口流出入シミュレーション（その３）(木曜)',
        '課題4-1 都市の人口流出入シミュレーション（その１）(火曜)',
        '課題4-2 都市の人口流出入シミュレーション（その２）(火曜)',
        '課題4-3 都市の人口流出入シミュレーション（その３）(火曜)',
        '課題4-1 放物線シミュレーション（１）(木曜)',
        '課題4-2 放物線シミュレーション（２）(木曜)',
        '課題4-3 放物線シミュレーション（３）(木曜)',
        '課題4-1 放物線シミュレーション（１）(火曜)',
        '課題4-2 放物線シミュレーション（２）(火曜)',
        '課題4-3 放物線シミュレーション（３）(火曜)']
kyoukasyo4=['教科書の内容の確認クイズ (1,2,3章)',
            '教科書の内容の確認クイズ (4章)',
            '教科書の内容の確認クイズ (5章)',
            '教科書の内容の確認クイズ (7章)',
            '教科書の内容の確認クイズ (6章) - 前回出題漏れのため再掲載',
            '教科書の内容の確認クイズ (8章)',
            '教科書の内容の確認クイズ (9章)']
#授業第5回目まで
kadai5=['課題1-1 関数の実装 (木曜)',
        '課題1-2 関数の実装と動作確認 (木曜)',
        '課題1-1 関数の実装 (火曜)',
        '課題1-2 関数の実装と動作確認 (火曜)',
        '課題1-2 Eclipseデバッガを使う (木曜)',
        '課題1-3 関数の実装と動作確認 (木曜)', 
        '課題1-2 Eclipseデバッガを使う (火曜)',
        '課題1-3 関数の実装と動作確認 (火曜)',
        '課題2-1: フローチャートとロジックの実装 (木曜)',
        '課題3-1 都市のデータを格納するクラス（その１） (木曜)',
        '課題3-2 都市のデータを格納するクラス（その２） (木曜)',
        '課題2-2：モンテカルロ法でπの近似値を計算 (木曜)',
        '課題2-1: フローチャートとロジックの実装 (火曜)',
        '課題2-2：モンテカルロ法でπの近似値を計算 (火曜)',
        '課題3-1 都市のデータを格納するクラス（その１） (火曜)',
        '課題3-2 都市のデータを格納するクラス（その２） (火曜)',
        '課題3-1 コンストラクタの作成（木曜）',
        '課題3-2 インスタンスメソッドの作成（木曜）',
        '課題3-3 クラスメソッドの作成（木曜）',
        '課題3-1 コンストラクタの作成（火曜）',
        '課題3-2 インスタンスメソッドの作成（火曜）',
        '課題3-3 クラスメソッドの作成（火曜）',
        '課題4-1 都市の人口流出入シミュレーション（その１）（木曜）',
        '課題4-2 都市の人口流出入シミュレーション（その２）（木曜）',
        '課題4-3 都市の人口流出入シミュレーション（その３）(木曜)',
        '課題4-1 都市の人口流出入シミュレーション（その１）(火曜)',
        '課題4-2 都市の人口流出入シミュレーション（その２）(火曜)',
        '課題4-3 都市の人口流出入シミュレーション（その３）(火曜)',
        '課題4-1 放物線シミュレーション（１）(木曜)',
        '課題4-2 放物線シミュレーション（２）(木曜)',
        '課題4-3 放物線シミュレーション（３）(木曜)',
        '課題4-1 放物線シミュレーション（１）(火曜)',
        '課題4-2 放物線シミュレーション（２）(火曜)',
        '課題4-3 放物線シミュレーション（３）(火曜)',
        '課題5-1 Countryクラスの導入 (木曜)',
        '課題5-2 ランキング用ソート (木曜)',
        '課題5-1 Countryクラスの導入 (火曜)',
        '課題5-2 ランキング用ソート (火曜)']
kyoukasyo5=['教科書の内容の確認クイズ (1,2,3章)',
            '教科書の内容の確認クイズ (4章)',
            '教科書の内容の確認クイズ (5章)',
            '教科書の内容の確認クイズ (7章)',
            '教科書の内容の確認クイズ (6章) - 前回出題漏れのため再掲載',
            '教科書の内容の確認クイズ (8章)',
            '教科書の内容の確認クイズ (9章)']
#授業第6回目まで
kadai6=['課題1-1 関数の実装 (木曜)',
        '課題1-2 関数の実装と動作確認 (木曜)',
        '課題1-1 関数の実装 (火曜)',
        '課題1-2 関数の実装と動作確認 (火曜)',
        '課題1-2 Eclipseデバッガを使う (木曜)',
        '課題1-3 関数の実装と動作確認 (木曜)', 
        '課題1-2 Eclipseデバッガを使う (火曜)',
        '課題1-3 関数の実装と動作確認 (火曜)',
        '課題2-1: フローチャートとロジックの実装 (木曜)',
        '課題3-1 都市のデータを格納するクラス（その１） (木曜)',
        '課題3-2 都市のデータを格納するクラス（その２） (木曜)',
        '課題2-2：モンテカルロ法でπの近似値を計算 (木曜)',
        '課題2-1: フローチャートとロジックの実装 (火曜)',
        '課題2-2：モンテカルロ法でπの近似値を計算 (火曜)',
        '課題3-1 都市のデータを格納するクラス（その１） (火曜)',
        '課題3-2 都市のデータを格納するクラス（その２） (火曜)',
        '課題3-1 コンストラクタの作成（木曜）',
        '課題3-2 インスタンスメソッドの作成（木曜）',
        '課題3-3 クラスメソッドの作成（木曜）',
        '課題3-1 コンストラクタの作成（火曜）',
        '課題3-2 インスタンスメソッドの作成（火曜）',
        '課題3-3 クラスメソッドの作成（火曜）',
        '課題4-1 都市の人口流出入シミュレーション（その１）（木曜）',
        '課題4-2 都市の人口流出入シミュレーション（その２）（木曜）',
        '課題4-3 都市の人口流出入シミュレーション（その３）(木曜)',
        '課題4-1 都市の人口流出入シミュレーション（その１）(火曜)',
        '課題4-2 都市の人口流出入シミュレーション（その２）(火曜)',
        '課題4-3 都市の人口流出入シミュレーション（その３）(火曜)',
        '課題4-1 放物線シミュレーション（１）(木曜)',
        '課題4-2 放物線シミュレーション（２）(木曜)',
        '課題4-3 放物線シミュレーション（３）(木曜)',
        '課題4-1 放物線シミュレーション（１）(火曜)',
        '課題4-2 放物線シミュレーション（２）(火曜)',
        '課題4-3 放物線シミュレーション（３）(火曜)',
        '課題5-1 Countryクラスの導入 (木曜)',
        '課題5-2 ランキング用ソート (木曜)',
        '課題5-1 Countryクラスの導入 (火曜)',
        '課題5-2 ランキング用ソート (火曜)',
        '課題6-1 メソッドの使用 (木曜)',
        '課題6-2 Comparableへの対応 (木曜)',
        '課題6-1 メソッドの使用 (火曜)',
        '課題6-2 Comparableへの対応 (火曜)']
kyoukasyo6=['教科書の内容の確認クイズ (1,2,3章)',
            '教科書の内容の確認クイズ (4章)',
            '教科書の内容の確認クイズ (5章)',
            '教科書の内容の確認クイズ (7章)',
            '教科書の内容の確認クイズ (6章) - 前回出題漏れのため再掲載',
            '教科書の内容の確認クイズ (8章)',
            '教科書の内容の確認クイズ (9章)']
#中間試験
#授業第７回目まで
kadai7=['課題1-1 関数の実装 (木曜)',
        '課題1-2 関数の実装と動作確認 (木曜)',
        '課題1-1 関数の実装 (火曜)',
        '課題1-2 関数の実装と動作確認 (火曜)',
        '課題1-2 Eclipseデバッガを使う (木曜)',
        '課題1-3 関数の実装と動作確認 (木曜)', 
        '課題1-2 Eclipseデバッガを使う (火曜)',
        '課題1-3 関数の実装と動作確認 (火曜)',
        '課題2-1: フローチャートとロジックの実装 (木曜)',
        '課題3-1 都市のデータを格納するクラス（その１） (木曜)',
        '課題3-2 都市のデータを格納するクラス（その２） (木曜)',
        '課題2-2：モンテカルロ法でπの近似値を計算 (木曜)',
        '課題2-1: フローチャートとロジックの実装 (火曜)',
        '課題2-2：モンテカルロ法でπの近似値を計算 (火曜)',
        '課題3-1 都市のデータを格納するクラス（その１） (火曜)',
        '課題3-2 都市のデータを格納するクラス（その２） (火曜)',
        '課題3-1 コンストラクタの作成（木曜）',
        '課題3-2 インスタンスメソッドの作成（木曜）',
        '課題3-3 クラスメソッドの作成（木曜）',
        '課題3-1 コンストラクタの作成（火曜）',
        '課題3-2 インスタンスメソッドの作成（火曜）',
        '課題3-3 クラスメソッドの作成（火曜）',
        '課題4-1 都市の人口流出入シミュレーション（その１）（木曜）',
        '課題4-2 都市の人口流出入シミュレーション（その２）（木曜）',
        '課題4-3 都市の人口流出入シミュレーション（その３）(木曜)',
        '課題4-1 都市の人口流出入シミュレーション（その１）(火曜)',
        '課題4-2 都市の人口流出入シミュレーション（その２）(火曜)',
        '課題4-3 都市の人口流出入シミュレーション（その３）(火曜)',
        '課題4-1 放物線シミュレーション（１）(木曜)',
        '課題4-2 放物線シミュレーション（２）(木曜)',
        '課題4-3 放物線シミュレーション（３）(木曜)',
        '課題4-1 放物線シミュレーション（１）(火曜)',
        '課題4-2 放物線シミュレーション（２）(火曜)',
        '課題4-3 放物線シミュレーション（３）(火曜)',
        '課題5-1 Countryクラスの導入 (木曜)',
        '課題5-2 ランキング用ソート (木曜)',
        '課題5-1 Countryクラスの導入 (火曜)',
        '課題5-2 ランキング用ソート (火曜)',
        '課題6-1 メソッドの使用 (木曜)',
        '課題6-2 Comparableへの対応 (木曜)',
        '課題6-1 メソッドの使用 (火曜)',
        '課題6-2 Comparableへの対応 (火曜)',
        '課題7-1 クラスの継承(PointCard)（木曜）',
        '課題7-2 簡易データベース1（木曜）',
        '課題7-3 簡易データベース2（木曜）',
        '課題7-1 クラスの継承(PointCard)',
        '課題7-2 簡易データベース1',
        '課題7-3 簡易データベース2',
        '課題7-1 プレイヤーの情報を扱うPlayerクラスの実装 (木曜)',
        '課題7-2 ゲームの基本機能を担うGameMainクラスの実装(1) (木曜)',
        '課題7-3 ゲームの基本機能を担うGameMainクラスの実装(2) (木曜)',
        '課題7-1 プレイヤーの情報を扱うPlayerクラスの実装 (火曜)',
        '課題7-2 ゲームの基本機能を担うGameMainクラスの実装(1) (火曜)',
        '課題7-3 ゲームの基本機能を担うGameMainクラスの実装(2) (火曜)']
kyoukasyo7=['教科書の内容の確認クイズ (1,2,3章)',
            '教科書の内容の確認クイズ (4章)',
            '教科書の内容の確認クイズ (5章)',
            '教科書の内容の確認クイズ (7章)',
            '教科書の内容の確認クイズ (6章) - 前回出題漏れのため再掲載',
            '教科書の内容の確認クイズ (8章)',
            '教科書の内容の確認クイズ (9章)',
            '教科書の内容の確認クイズ (10章)',
            '教科書の内容の確認クイズ (11章)']
#授業第8回目まで
kadai8=['課題1-1 関数の実装 (木曜)',
        '課題1-2 関数の実装と動作確認 (木曜)',
        '課題1-1 関数の実装 (火曜)',
        '課題1-2 関数の実装と動作確認 (火曜)',
        '課題1-2 Eclipseデバッガを使う (木曜)',
        '課題1-3 関数の実装と動作確認 (木曜)', 
        '課題1-2 Eclipseデバッガを使う (火曜)',
        '課題1-3 関数の実装と動作確認 (火曜)',
        '課題2-1: フローチャートとロジックの実装 (木曜)',
        '課題3-1 都市のデータを格納するクラス（その１） (木曜)',
        '課題3-2 都市のデータを格納するクラス（その２） (木曜)',
        '課題2-2：モンテカルロ法でπの近似値を計算 (木曜)',
        '課題2-1: フローチャートとロジックの実装 (火曜)',
        '課題2-2：モンテカルロ法でπの近似値を計算 (火曜)',
        '課題3-1 都市のデータを格納するクラス（その１） (火曜)',
        '課題3-2 都市のデータを格納するクラス（その２） (火曜)',
        '課題3-1 コンストラクタの作成（木曜）',
        '課題3-2 インスタンスメソッドの作成（木曜）',
        '課題3-3 クラスメソッドの作成（木曜）',
        '課題3-1 コンストラクタの作成（火曜）',
        '課題3-2 インスタンスメソッドの作成（火曜）',
        '課題3-3 クラスメソッドの作成（火曜）',
        '課題4-1 都市の人口流出入シミュレーション（その１）（木曜）',
        '課題4-2 都市の人口流出入シミュレーション（その２）（木曜）',
        '課題4-3 都市の人口流出入シミュレーション（その３）(木曜)',
        '課題4-1 都市の人口流出入シミュレーション（その１）(火曜)',
        '課題4-2 都市の人口流出入シミュレーション（その２）(火曜)',
        '課題4-3 都市の人口流出入シミュレーション（その３）(火曜)',
        '課題4-1 放物線シミュレーション（１）(木曜)',
        '課題4-2 放物線シミュレーション（２）(木曜)',
        '課題4-3 放物線シミュレーション（３）(木曜)',
        '課題4-1 放物線シミュレーション（１）(火曜)',
        '課題4-2 放物線シミュレーション（２）(火曜)',
        '課題4-3 放物線シミュレーション（３）(火曜)',
        '課題5-1 Countryクラスの導入 (木曜)',
        '課題5-2 ランキング用ソート (木曜)',
        '課題5-1 Countryクラスの導入 (火曜)',
        '課題5-2 ランキング用ソート (火曜)',
        '課題6-1 メソッドの使用 (木曜)',
        '課題6-2 Comparableへの対応 (木曜)',
        '課題6-1 メソッドの使用 (火曜)',
        '課題6-2 Comparableへの対応 (火曜)',
        '課題7-1 クラスの継承(PointCard)（木曜）',
        '課題7-2 簡易データベース1（木曜）',
        '課題7-3 簡易データベース2（木曜）',
        '課題7-1 クラスの継承(PointCard)',
        '課題7-2 簡易データベース1',
        '課題7-3 簡易データベース2',
        '課題7-1 プレイヤーの情報を扱うPlayerクラスの実装 (木曜)',
        '課題7-2 ゲームの基本機能を担うGameMainクラスの実装(1) (木曜)',
        '課題7-3 ゲームの基本機能を担うGameMainクラスの実装(2) (木曜)',
        '課題7-1 プレイヤーの情報を扱うPlayerクラスの実装 (火曜)',
        '課題7-2 ゲームの基本機能を担うGameMainクラスの実装(1) (火曜)',
        '課題7-3 ゲームの基本機能を担うGameMainクラスの実装(2) (火曜)',
        '課題8-1 自治体のオープンデータから統計情報を求める（その１）(木曜)',
        '課題8-2 自治体のオープンデータから統計情報を求める（その２）(木曜)',
        '課題8-1 自治体のオープンデータから統計情報を求める（その１）(火曜)',
        '課題8-2 自治体のオープンデータから統計情報を求める（その２）(火曜)',
        '課題8-2 自治体のオープンデータから統計情報を求める（その２）(火曜) - 欠席者用',
        '課題8-1「豚のしっぽ」プログラムの作成 (1) (木曜)',
        '課題8-2「豚のしっぽ」プログラムの作成 (2) (木曜)',
        '課題8-3「豚のしっぽ」プログラムの作成 (3) (木曜)',
        '課題8-1「豚のしっぽ」プログラムの作成 (1) (火曜)',
        '課題8-2「豚のしっぽ」プログラムの作成 (2) (火曜)',
        '課題8-3「豚のしっぽ」プログラムの作成 (3) (火曜)']
kyoukasyo8=['教科書の内容の確認クイズ (1,2,3章)',
            '教科書の内容の確認クイズ (4章)',
            '教科書の内容の確認クイズ (5章)',
            '教科書の内容の確認クイズ (7章)',
            '教科書の内容の確認クイズ (6章) - 前回出題漏れのため再掲載',
            '教科書の内容の確認クイズ (8章)',
            '教科書の内容の確認クイズ (9章)',
            '教科書の内容の確認クイズ (10章)',
            '教科書の内容の確認クイズ (11章)',
            '教科書の内容の確認クイズ (12章)',
            '教科書の内容の確認クイズ (13章)']
#授業第9回目まで
kadai9=['課題1-1 関数の実装 (木曜)',
        '課題1-2 関数の実装と動作確認 (木曜)',
        '課題1-1 関数の実装 (火曜)',
        '課題1-2 関数の実装と動作確認 (火曜)',
        '課題1-2 Eclipseデバッガを使う (木曜)',
        '課題1-3 関数の実装と動作確認 (木曜)', 
        '課題1-2 Eclipseデバッガを使う (火曜)',
        '課題1-3 関数の実装と動作確認 (火曜)',
        '課題2-1: フローチャートとロジックの実装 (木曜)',
        '課題3-1 都市のデータを格納するクラス（その１） (木曜)',
        '課題3-2 都市のデータを格納するクラス（その２） (木曜)',
        '課題2-2：モンテカルロ法でπの近似値を計算 (木曜)',
        '課題2-1: フローチャートとロジックの実装 (火曜)',
        '課題2-2：モンテカルロ法でπの近似値を計算 (火曜)',
        '課題3-1 都市のデータを格納するクラス（その１） (火曜)',
        '課題3-2 都市のデータを格納するクラス（その２） (火曜)',
        '課題3-1 コンストラクタの作成（木曜）',
        '課題3-2 インスタンスメソッドの作成（木曜）',
        '課題3-3 クラスメソッドの作成（木曜）',
        '課題3-1 コンストラクタの作成（火曜）',
        '課題3-2 インスタンスメソッドの作成（火曜）',
        '課題3-3 クラスメソッドの作成（火曜）',
        '課題4-1 都市の人口流出入シミュレーション（その１）（木曜）',
        '課題4-2 都市の人口流出入シミュレーション（その２）（木曜）',
        '課題4-3 都市の人口流出入シミュレーション（その３）(木曜)',
        '課題4-1 都市の人口流出入シミュレーション（その１）(火曜)',
        '課題4-2 都市の人口流出入シミュレーション（その２）(火曜)',
        '課題4-3 都市の人口流出入シミュレーション（その３）(火曜)',
        '課題4-1 放物線シミュレーション（１）(木曜)',
        '課題4-2 放物線シミュレーション（２）(木曜)',
        '課題4-3 放物線シミュレーション（３）(木曜)',
        '課題4-1 放物線シミュレーション（１）(火曜)',
        '課題4-2 放物線シミュレーション（２）(火曜)',
        '課題4-3 放物線シミュレーション（３）(火曜)',
        '課題5-1 Countryクラスの導入 (木曜)',
        '課題5-2 ランキング用ソート (木曜)',
        '課題5-1 Countryクラスの導入 (火曜)',
        '課題5-2 ランキング用ソート (火曜)',
        '課題6-1 メソッドの使用 (木曜)',
        '課題6-2 Comparableへの対応 (木曜)',
        '課題6-1 メソッドの使用 (火曜)',
        '課題6-2 Comparableへの対応 (火曜)',
        '課題7-1 クラスの継承(PointCard)（木曜）',
        '課題7-2 簡易データベース1（木曜）',
        '課題7-3 簡易データベース2（木曜）',
        '課題7-1 クラスの継承(PointCard)',
        '課題7-2 簡易データベース1',
        '課題7-3 簡易データベース2',
        '課題7-1 プレイヤーの情報を扱うPlayerクラスの実装 (木曜)',
        '課題7-2 ゲームの基本機能を担うGameMainクラスの実装(1) (木曜)',
        '課題7-3 ゲームの基本機能を担うGameMainクラスの実装(2) (木曜)',
        '課題7-1 プレイヤーの情報を扱うPlayerクラスの実装 (火曜)',
        '課題7-2 ゲームの基本機能を担うGameMainクラスの実装(1) (火曜)',
        '課題7-3 ゲームの基本機能を担うGameMainクラスの実装(2) (火曜)',
        '課題8-1 自治体のオープンデータから統計情報を求める（その１）(木曜)',
        '課題8-2 自治体のオープンデータから統計情報を求める（その２）(木曜)',
        '課題8-1 自治体のオープンデータから統計情報を求める（その１）(火曜)',
        '課題8-2 自治体のオープンデータから統計情報を求める（その２）(火曜)',
        '課題8-2 自治体のオープンデータから統計情報を求める（その２）(火曜) - 欠席者用',
        '課題8-1「豚のしっぽ」プログラムの作成 (1) (木曜)',
        '課題8-2「豚のしっぽ」プログラムの作成 (2) (木曜)',
        '課題8-3「豚のしっぽ」プログラムの作成 (3) (木曜)',
        '課題8-1「豚のしっぽ」プログラムの作成 (1) (火曜)',
        '課題8-2「豚のしっぽ」プログラムの作成 (2) (火曜)',
        '課題8-3「豚のしっぽ」プログラムの作成 (3) (火曜)',
        '課題9-1 簡易テキストマイニング（その１）(木曜)',
        '課題9-2 簡易テキストマイニング（その２）(木曜)',
        '課題9-1 簡易テキストマイニング（その１）(火曜)',
        '課題9-2 簡易テキストマイニング（その２）(火曜)']
kyoukasyo9=['教科書の内容の確認クイズ (1,2,3章)',
            '教科書の内容の確認クイズ (4章)',
            '教科書の内容の確認クイズ (5章)',
            '教科書の内容の確認クイズ (7章)',
            '教科書の内容の確認クイズ (6章) - 前回出題漏れのため再掲載',
            '教科書の内容の確認クイズ (8章)',
            '教科書の内容の確認クイズ (9章)',
            '教科書の内容の確認クイズ (10章)',
            '教科書の内容の確認クイズ (11章)',
            '教科書の内容の確認クイズ (12章)',
            '教科書の内容の確認クイズ (13章)']
#授業第10回目まで
kadai10=['課題1-1 関数の実装 (木曜)',
        '課題1-2 関数の実装と動作確認 (木曜)',
        '課題1-1 関数の実装 (火曜)',
        '課題1-2 関数の実装と動作確認 (火曜)',
        '課題1-2 Eclipseデバッガを使う (木曜)',
        '課題1-3 関数の実装と動作確認 (木曜)', 
        '課題1-2 Eclipseデバッガを使う (火曜)',
        '課題1-3 関数の実装と動作確認 (火曜)',
        '課題2-1: フローチャートとロジックの実装 (木曜)',
        '課題3-1 都市のデータを格納するクラス（その１） (木曜)',
        '課題3-2 都市のデータを格納するクラス（その２） (木曜)',
        '課題2-2：モンテカルロ法でπの近似値を計算 (木曜)',
        '課題2-1: フローチャートとロジックの実装 (火曜)',
        '課題2-2：モンテカルロ法でπの近似値を計算 (火曜)',
        '課題3-1 都市のデータを格納するクラス（その１） (火曜)',
        '課題3-2 都市のデータを格納するクラス（その２） (火曜)',
        '課題3-1 コンストラクタの作成（木曜）',
        '課題3-2 インスタンスメソッドの作成（木曜）',
        '課題3-3 クラスメソッドの作成（木曜）',
        '課題3-1 コンストラクタの作成（火曜）',
        '課題3-2 インスタンスメソッドの作成（火曜）',
        '課題3-3 クラスメソッドの作成（火曜）',
        '課題4-1 都市の人口流出入シミュレーション（その１）（木曜）',
        '課題4-2 都市の人口流出入シミュレーション（その２）（木曜）',
        '課題4-3 都市の人口流出入シミュレーション（その３）(木曜)',
        '課題4-1 都市の人口流出入シミュレーション（その１）(火曜)',
        '課題4-2 都市の人口流出入シミュレーション（その２）(火曜)',
        '課題4-3 都市の人口流出入シミュレーション（その３）(火曜)',
        '課題4-1 放物線シミュレーション（１）(木曜)',
        '課題4-2 放物線シミュレーション（２）(木曜)',
        '課題4-3 放物線シミュレーション（３）(木曜)',
        '課題4-1 放物線シミュレーション（１）(火曜)',
        '課題4-2 放物線シミュレーション（２）(火曜)',
        '課題4-3 放物線シミュレーション（３）(火曜)',
        '課題5-1 Countryクラスの導入 (木曜)',
        '課題5-2 ランキング用ソート (木曜)',
        '課題5-1 Countryクラスの導入 (火曜)',
        '課題5-2 ランキング用ソート (火曜)',
        '課題6-1 メソッドの使用 (木曜)',
        '課題6-2 Comparableへの対応 (木曜)',
        '課題6-1 メソッドの使用 (火曜)',
        '課題6-2 Comparableへの対応 (火曜)',
        '課題7-1 クラスの継承(PointCard)（木曜）',
        '課題7-2 簡易データベース1（木曜）',
        '課題7-3 簡易データベース2（木曜）',
        '課題7-1 クラスの継承(PointCard)',
        '課題7-2 簡易データベース1',
        '課題7-3 簡易データベース2',
        '課題7-1 プレイヤーの情報を扱うPlayerクラスの実装 (木曜)',
        '課題7-2 ゲームの基本機能を担うGameMainクラスの実装(1) (木曜)',
        '課題7-3 ゲームの基本機能を担うGameMainクラスの実装(2) (木曜)',
        '課題7-1 プレイヤーの情報を扱うPlayerクラスの実装 (火曜)',
        '課題7-2 ゲームの基本機能を担うGameMainクラスの実装(1) (火曜)',
        '課題7-3 ゲームの基本機能を担うGameMainクラスの実装(2) (火曜)',
        '課題8-1 自治体のオープンデータから統計情報を求める（その１）(木曜)',
        '課題8-2 自治体のオープンデータから統計情報を求める（その２）(木曜)',
        '課題8-1 自治体のオープンデータから統計情報を求める（その１）(火曜)',
        '課題8-2 自治体のオープンデータから統計情報を求める（その２）(火曜)',
        '課題8-2 自治体のオープンデータから統計情報を求める（その２）(火曜) - 欠席者用',
        '課題8-1「豚のしっぽ」プログラムの作成 (1) (木曜)',
        '課題8-2「豚のしっぽ」プログラムの作成 (2) (木曜)',
        '課題8-3「豚のしっぽ」プログラムの作成 (3) (木曜)',
        '課題8-1「豚のしっぽ」プログラムの作成 (1) (火曜)',
        '課題8-2「豚のしっぽ」プログラムの作成 (2) (火曜)',
        '課題8-3「豚のしっぽ」プログラムの作成 (3) (火曜)',
        '課題9-1 簡易テキストマイニング（その１）(木曜)',
        '課題9-2 簡易テキストマイニング（その２）(木曜)',
        '課題9-1 簡易テキストマイニング（その１）(火曜)',
        '課題9-2 簡易テキストマイニング（その２）(火曜)',
        '課題10-1 Personクラスの導入 (木曜)',
        '課題10-2 簡易レコメンデーションの改良 (木曜)',
        '課題10-1 Personクラスの導入 (火曜)',
        '課題10-2 簡易レコメンデーションの改良 (火曜)',
        '課題10-1 テキスト群からの特徴語抽出(その1) (木曜)',
        '課題10-2 テキスト群からの特徴語抽出(その2) (木曜)',
        '課題10-1 テキスト群からの特徴語抽出(その1) (火曜)',
        '課題10-2 テキスト群からの特徴語抽出(その2) (火曜)']
kyoukasyo10=['教科書の内容の確認クイズ (1,2,3章)',
            '教科書の内容の確認クイズ (4章)',
            '教科書の内容の確認クイズ (5章)',
            '教科書の内容の確認クイズ (7章)',
            '教科書の内容の確認クイズ (6章) - 前回出題漏れのため再掲載',
            '教科書の内容の確認クイズ (8章)',
            '教科書の内容の確認クイズ (9章)',
            '教科書の内容の確認クイズ (10章)',
            '教科書の内容の確認クイズ (11章)',
            '教科書の内容の確認クイズ (12章)',
            '教科書の内容の確認クイズ (13章)']

# %%
#Unnamed: 0除外
df2_3=df2_2[["userid","name","submitnumber","score"]]
df2_3
# Out:
#       userid                   name  submitnumber     score
# 3565  182233  教科書の内容の確認クイズ (1,2,3章)             1   8.00000
# 801   182233     教科書の内容の確認クイズ (10章)             1   8.00000
# 1067  182233     教科書の内容の確認クイズ (11章)             1  10.00000
# 2089  182233     教科書の内容の確認クイズ (12章)             1  12.00000
# 2072  182233     教科書の内容の確認クイズ (13章)             1   8.00000
# ...      ...                    ...           ...       ...
# 8059  193734      教科書の内容の確認クイズ (8章)             1   3.00000
# 8326  193734      教科書の内容の確認クイズ (9章)             1   2.57143
# 8327  193734      教科書の内容の確認クイズ (9章)             2   2.57143
# 8328  193734      教科書の内容の確認クイズ (9章)             3   3.00000
# 8329  193734      教科書の内容の確認クイズ (9章)             4   3.00000
#
# [11607 rows x 4 columns]

# %%
cdefjkl1819=[]
df18_3_1 = pd.read_csv('testxl18.csv')
df19_3_1 = pd.read_csv('testxl19.csv')
#list20_3 = df20_3['userid'].unique().tolist()
list18_3_2 = df18_3_1['userid'].unique().tolist()
list19_3_2 = df19_3_1['userid'].unique().tolist()
cdefjkl1819.extend(list18_3_2)
cdefjkl1819.extend(list19_3_2)
cdefjkl1819
# Out:
# [182233,
#  182324,
#  182669,
#  182771,
#  182787,
#  183117,
#  183119,
#  183120,
#  183123,
#  183125,
#  183126,
#  183127,
#  183128,
#  183131,
#  183132,
#  183134,
#  183135,
#  183137,
#  183138,
#  183139,
#  183143,
#  183145,
#  183146,
#  183148,
#  183150,
#  183152,
#  183154,
#  183155,
#  183156,
#  183157,
#  183158,
#  183159,
#  183161,
#  183166,
#  183170,
#  183171,
#  183172,
#  183174,
#  183176,
#  183179,
#  183183,
#  183185,
#  183186,
#  183187,
#  183188,
#  183189,
#  183190,
#  183192,
#  183193,
#  183194,
#  183196,
#  183197,
#  183201,
#  183202,
#  183205,
#  183206,
#  183209,
#  183210,
#  183212,
#  183214,
#  183217,
#  183219,
#  183225,
#  183226,
#  183227,
#  183228,
#  183229,
#  183231,
#  183232,
#  183234,
#  183235,
#  183236,
#  183237,
#  183238,
#  183239,
#  183240,
#  183243,
#  183246,
#  183249,
#  183250,
#  183252,
#  183254,
#  183255,
#  183257,
#  183260,
#  183261,
#  183263,
#  183264,
#  183265,
#  183266,
# ...

# %%
#18,19年度のCDEFクラスの学生(userid)をリスト化
CDEF18=[183306, 183335, 183333, 183189, 183202, 183250, 183158, 183339, 183219, 183291, 183155, 183265, 183127, 183270, 183308, 183288, 183183, 183301, 183201, 183226, 183237, 183266, 183161, 183143, 183354, 183232, 183134, 183316, 183150, 183343, 183174, 183267, 183166, 183277, 183257, 183350, 183187, 183246, 183190, 183320, 183319, 183212, 183263, 183271, 183193, 183239, 183243, 183132, 183285, 183310, 183330, 183314, 183210, 183254, 183217, 183192, 183269, 183227, 183172, 183197, 183206, 183268, 183360, 183205, 183214, 183229, 183260, 183298, 183196, 183148, 183157, 183261, 183126, 183156, 183209, 183313, 183249, 183276, 183289, 183315]
CDEF19=[193487, 193489, 193494, 193496, 193503, 193506, 193511, 193512, 193520, 193522, 193543, 193544, 193548, 193551, 193564, 193565, 193576, 193579, 193590, 193591, 193602, 193607, 193615, 193627, 193634, 193635, 193642, 193643, 193646, 193648, 193663, 193664, 193673, 193679, 193699, 193703, 193718, 193720, 193727, 193729, 193283, 193168, 193321, 193485, 193497, 193505, 193510, 193519, 193527, 193530, 193556, 193558, 193566, 193573, 193581, 193587, 193600, 193612, 193616, 193617, 193621, 193623, 193624, 193625, 193628, 193632, 193638, 193649, 193650, 193670, 193677, 193682, 193685, 193700, 193706, 193707, 193715, 193716, 193722, 193725, 193730]
CDEF1819=[183306, 183335, 183333, 183189, 183202, 183250, 183158, 183339, 183219, 183291, 183155, 183265, 183127, 183270, 183308, 183288, 183183, 183301, 183201, 183226, 183237, 183266, 183161, 183143, 183354, 183232, 183134, 183316, 183150, 183343, 183174, 183267, 183166, 183277, 183257, 183350, 183187, 183246, 183190, 183320, 183319, 183212, 183263, 183271, 183193, 183239, 183243, 183132, 183285, 183310, 183330, 183314, 183210, 183254, 183217, 183192, 183269, 183227, 183172, 183197, 183206, 183268, 183360, 183205, 183214, 183229, 183260, 183298, 183196, 183148, 183157, 183261, 183126, 183156, 183209, 183313, 183249, 183276, 183289, 183315, 193487, 193489, 193494, 193496, 193503, 193506, 193511, 193512, 193520, 193522, 193543, 193544, 193548, 193551, 193564, 193565, 193576, 193579, 193590, 193591, 193602, 193607, 193615, 193627, 193634, 193635, 193642, 193643, 193646, 193648, 193663, 193664, 193673, 193679, 193699, 193703, 193718, 193720, 193727, 193729, 193283, 193168, 193321, 193485, 193497, 193505, 193510, 193519, 193527, 193530, 193556, 193558, 193566, 193573, 193581, 193587, 193600, 193612, 193616, 193617, 193621, 193623, 193624, 193625, 193628, 193632, 193638, 193649, 193650, 193670, 193677, 193682, 193685, 193700, 193706, 193707, 193715, 193716, 193722, 193725, 193730]

# %%
cdefjkl1819.extend(CDEF1819)
cdefjkl1819_st=sorted(cdefjkl1819)
cdefjkl1819_2=list(set(cdefjkl1819_st))
cdefjkl1819_2.remove(193316)
cdefjkl1819_2.remove(193350)
cdefjkl1819_2.remove(193362)
len(cdefjkl1819_2)
# Out:
# 289

# %%
len(kadai10)
# Out:
# 77

# %%
#対象クラス・年度の学生抽出
df1_4=df_3[df_3['userid'].isin(cdefjkl1819_2)]
df2_4=df2_3[df2_3['userid'].isin(cdefjkl1819_2)]
df1_4
# Out:
#        userid                            name  submitnumber  score
# 0      182233                課題1-1 関数の実装 (木曜)             8   10.0
# 1      182233           課題1-2 関数の実装と動作確認 (木曜)             1    3.6
# 2      182233        課題10-1 Personクラスの導入 (木曜)             1    0.0
# 3      182233     課題2-1: フローチャートとロジックの実装 (木曜)            11    3.0
# 4      182233  課題3-1 都市のデータを格納するクラス（その１） (木曜)             2   10.0
# ...       ...                             ...           ...    ...
# 14381  193734      課題9-1 簡易テキストマイニング（その１）(木曜)             6   10.0
# 14382  193734      課題9-2 簡易テキストマイニング（その２）(木曜)             1   10.0
# 14383  193734             課題Python (IDF) (木曜)             1   10.0
# 14384  193734              課題Python (TF) (木曜)             3   10.0
# 14385  193734          課題Python (TF-IDF) (木曜)             3   10.0
#
# [7578 rows x 4 columns]

# %%
kadai_list=kadai10
kyoukasyo_list=kyoukasyo10

# %%
#課題名が一致するデータだけを抽出（df1_4,df2_4から）
df1_5=df1_4[df1_4['name'].isin(kadai10)]
df2_5=df2_4[df2_4['name'].isin(kyoukasyo10)]
df1_5[df1_5['userid']==193564]
# Out:
#        userid                                     name  submitnumber  score
# 11073  193564                         課題1-1 関数の実装 (火曜)             1   10.0
# 11074  193564                課題1-2 Eclipseデバッガを使う (火曜)             1    1.0
# 11075  193564                    課題1-3 関数の実装と動作確認 (火曜)             1   10.0
# 11076  193564           課題10-1 テキスト群からの特徴語抽出(その1) (火曜)             2   10.0
# 11077  193564           課題10-2 テキスト群からの特徴語抽出(その2) (火曜)             3   10.0
# 11078  193564              課題2-1: フローチャートとロジックの実装 (火曜)             1   10.0
# 11079  193564              課題2-2：モンテカルロ法でπの近似値を計算 (火曜)             1   10.0
# 11080  193564                     課題3-1 コンストラクタの作成（火曜）             2   10.0
# 11081  193564                  課題3-2 インスタンスメソッドの作成（火曜）             3   10.0
# 11082  193564                     課題3-3 クラスメソッドの作成（火曜）             3   10.0
# 11083  193564                 課題4-1 放物線シミュレーション（１）(火曜)             1   10.0
# ...

# %%
#group化して、scoreのmaxを抽出→その時の提出回数目も抽出される
df1_6=df1_5.sort_values(['userid','name','submitnumber'])
df1_7=df1_6.groupby(['userid','name']).max()
df2_6=df2_5.sort_values(['userid','name','submitnumber'])
df2_7=df2_6.groupby(['userid','name']).max()
df1_7_2=df1_6.groupby('userid').sum()
df1_7_2.to_csv('goukei_kad.csv')
df1_7_3=pd.read_csv('goukei_kad.csv')
df1_7_3['score_kad_ave']=df1_7_3['score']/25
df1_7_4=df1_7_3[['userid','score_kad_ave']].round(2)
df1_7_4
# Out:
#      userid  score_kad_ave
# 0    182233           2.87
# 1    182324           8.56
# 2    182669           7.60
# 3    182771           6.35
# 4    182787           5.04
# 5    183117           8.80
# 6    183119           8.40
# 7    183120           8.72
# 8    183123           8.80
# 9    183125           8.40
# 10   183126           8.64
# 11   183127           8.48
# 12   183128           8.64
# 13   183131           8.64
# 14   183132           7.84
# 15   183134           8.48
# 16   183135           8.72
# 17   183137           8.56
# 18   183138           8.52
# 19   183139           6.68
# 20   183143           8.72
# 21   183145           8.64
# 22   183146           7.84
# 23   183148           8.24
# 24   183150           8.40
# 25   183152           8.72
# 26   183154           8.62
# 27   183155           8.08
# 28   183156           8.56
# 29   183157           7.44
# 30   183158           8.64
# 31   183159           8.72
# 32   183161           8.80
# ...

# %%
#課題　提出回数の平均とスコアの平均を学生毎に算出
df1_8=df1_7[["submitnumber"]].groupby("userid").mean().round(2)
df1_9_0=df1_8.rename(columns={'submitnumber': 'submitnum_kad_ave'})
df1_9_0.to_csv('submitnum_kad_ave.csv')
df1_9_1=pd.read_csv('submitnum_kad_ave.csv')
df1_9 = pd.merge(df1_7_4,df1_9_1[["userid","submitnum_kad_ave"]], on = "userid", how = "left")
df1_9
# Out:
#      userid  score_kad_ave  submitnum_kad_ave
# 0    182233           2.87               3.62
# 1    182324           8.56               2.23
# 2    182669           7.60               3.20
# 3    182771           6.35               4.33
# 4    182787           5.04               2.40
# 5    183117           8.80               3.00
# 6    183119           8.40               2.23
# 7    183120           8.72               3.45
# 8    183123           8.80               3.18
# 9    183125           8.40               3.32
# 10   183126           8.64               3.09
# 11   183127           8.48               3.68
# 12   183128           8.64               4.18
# 13   183131           8.64               2.45
# 14   183132           7.84               2.86
# 15   183134           8.48               2.82
# 16   183135           8.72               2.59
# 17   183137           8.56               2.18
# 18   183138           8.52               1.91
# ...

# %%
#教科書クイズ提出回数の平均
df2_8=df2_7[["submitnumber"]].groupby("userid").mean().round(2)
df2_9=df2_8.rename(columns={'submitnumber':'submitnum_kyou_ave'})
df2_9
# Out:
#         submitnum_kyou_ave
# userid
# 182233                1.00
# 182324                1.64
# 182669                1.55
# 182771                1.45
# 182787                1.80
# 183117                1.82
# 183119                2.09
# 183120                2.64
# 183123                1.82
# 183125                2.36
# 183126                1.36
# 183127                1.82
# 183128                2.64
# 183131                2.00
# 183132                2.36
# 183134                2.27
# 183135                2.27
# 183137                1.90
# 183138                1.18
# 183139                2.55
# 183143                2.55
# 183145                1.36
# 183146                1.55
# 183148                2.18
# 183150                1.91
# 183152                4.27
# 183154                2.00
# 183155                1.27
# 183156                1.45
# 183157                2.18
# 183158                1.27
# 183159                2.00
# 183161                1.27
# ...

# %%
#「満点の課題の回数」を追加
#課題の全提出(課題抽出済)から最終提出のデータを抽出
df3_1=df1_5.groupby(["userid","name"]).max()
df3_1.to_csv("maxtotyuu.csv")
df123=pd.read_csv('maxtotyuu.csv')
df3_2=df3_1[["submitnumber","score"]]
#授業内で満点取れたデータの抽出
df3_3=df3_2[df3_2['score'] == 10.0]
#授業内で満点取れたデータの個数を算出
df3_4=df3_3.groupby("userid").count()
df3_5=df3_4[["score"]]
df3_5.to_csv("max_count.csv")
df3_6=pd.read_csv('max_count.csv')
#学生抽出
#df3_7=df3_6[df3_6['userid'].isin(CDEF1819)]
df3_8=df3_6.rename(columns={'score': 'kad_perfectscore_count'})
df3_8
# Out:
#      userid  kad_perfectscore_count
# 0    182233                       4
# 1    182324                      19
# 2    182669                      19
# 3    182771                      13
# 4    182787                      12
# 5    183117                      22
# 6    183119                      21
# 7    183120                      21
# 8    183123                      22
# 9    183125                      21
# 10   183126                      20
# 11   183127                      18
# 12   183128                      20
# 13   183131                      20
# 14   183132                      11
# 15   183134                      18
# 16   183135                      21
# 17   183137                      19
# 18   183138                      21
# 19   183139                      15
# 20   183143                      21
# 21   183145                      20
# 22   183146                      18
# 23   183148                      17
# 24   183150                      21
# ...

# %%
df3_9=df3_8[df3_8['kad_perfectscore_count']>24]
df3_9
# Out:
# Empty DataFrame
# Columns: [userid, kad_perfectscore_count]
# Index: []

# %%
df125=df123[df123['userid']==193316]
df125
# Out:
# Empty DataFrame
# Columns: [userid, name, submitnumber, score]
# Index: []

# %%
#中間・期末テストの点数抽出
df4_1=pd.read_csv("testxl1819.csv")
df4_2=df4_1[["userid","midtermtest","finaltest"]]
df4_2
# Out:
#      userid  midtermtest  finaltest
# 0    182233           24         34
# 1    182324           52         88
# 2    182669           59         55
# 3    182771           42         44
# 4    182787           46         54
# 5    183117           67         92
# 6    183119           84         81
# 7    183120           72         83
# 8    183123           81         88
# 9    183125           61         73
# 10   183126           88         84
# 11   183127           76         93
# 12   183128           69         77
# 13   183131           85         96
# 14   183132           58         66
# 15   183134           74         83
# 16   183135           63         70
# 17   183137           49         74
# 18   183138           96         96
# 19   183139           49         90
# 20   183143           75         74
# 21   183145           47         82
# 22   183146           73         91
# 23   183148           54         56
# 24   183150           95        100
# ...

# %%
#課題　提出回数の平均とスコアの平均 結合
df5_1 = pd.merge(df1_9,df4_2[["userid","midtermtest","finaltest"]], on = "userid", how = "left")
#教科書クイズ提出回数の平均 結合
df5_2 = pd.merge(df2_9,df5_1[["userid","submitnum_kad_ave","score_kad_ave","midtermtest","finaltest"]], on = "userid", how = "left")
#満点の課題の回数 結合
df5_3 = pd.merge(df3_8,df5_2[["userid","submitnum_kad_ave","score_kad_ave","submitnum_kyou_ave","midtermtest","finaltest"]], on = "userid", how = "left")
# Out:
#      userid  kad_perfectscore_count  submitnum_kad_ave  score_kad_ave  \
# 0    182233                       4               3.62           2.87
# 1    182324                      19               2.23           8.56
# 2    182669                      19               3.20           7.60
# 3    182771                      13               4.33           6.35
# 4    182787                      12               2.40           5.04
# 5    183117                      22               3.00           8.80
# 6    183119                      21               2.23           8.40
# 7    183120                      21               3.45           8.72
# 8    183123                      22               3.18           8.80
# 9    183125                      21               3.32           8.40
# 10   183126                      20               3.09           8.64
# 11   183127                      18               3.68           8.48
# ...

# %%
df5_4=df5_3[df5_3["userid"]<190000]
df5_4["kad_perfectscore_pro"]=df5_4["kad_perfectscore_count"]/22
df5_5=df5_4[["userid","kad_perfectscore_pro","submitnum_kad_ave","score_kad_ave","submitnum_kyou_ave","midtermtest","finaltest"]].round(2)
df5_4_1=df5_3[df5_3["userid"]>190000]
df5_4_1["kad_perfectscore_pro"]=df5_4_1["kad_perfectscore_count"]/25
df5_5_1=df5_4_1[["userid","kad_perfectscore_pro","submitnum_kad_ave","score_kad_ave","submitnum_kyou_ave","midtermtest","finaltest"]].round(2)
df5_6 = pd.concat([df5_5, df5_5_1])
df5_6
# Out:
# <ipython-input-42-2fb1dfc92686>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5_4["kad_perfectscore_pro"]=df5_4["kad_perfectscore_count"]/22
# <ipython-input-42-2fb1dfc92686>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5_4_1["kad_perfectscore_pro"]=df5_4_1["kad_perfectscore_count"]/25
#      userid  kad_perfectscore_pro  submitnum_kad_ave  score_kad_ave  \
# 0    182233                  0.18               3.62           2.87
# ...

# %%
df5_6.to_csv("saisinnbann_CDEFJKL1819_10.csv")

# %%
df_a1=pd.read_csv("saisinnbann_CDEFJKL1819_10.csv")
df_a2=pd.read_csv('./new_csv_kopiperuna-/kopipe_remove_motofile_2.csv')
df_a3=df_a2[['file_id','rate']]
df_a4=df_a3.rename(columns={'file_id':'userid'})
df_a4
# Out:
#      userid  rate
# 0    182213  97.1
# 1    182233  92.8
# 2    182324  96.2
# 3    182338  96.7
# 4    182669  97.1
# 5    182771  92.8
# 6    182787  97.0
# 7    183117  97.0
# 8    183119  97.0
# 9    183120  97.0
# 10   183123  96.2
# 11   183124  97.0
# 12   183125  97.0
# 13   183126  94.4
# 14   183127  83.3
# 15   183128  97.1
# 16   183131  97.1
# 17   183132  87.5
# 18   183134  97.0
# 19   183135  92.8
# 20   183137  97.0
# 21   183139  97.1
# 22   183143  84.2
# 23   183145  97.1
# 24   183146  97.0
# 25   183148  94.4
# 26   183150  97.1
# 27   183152  97.0
# 28   183154  97.0
# 29   183155  97.1
# 30   183156  97.1
# 31   183157  97.0
# 32   183158  94.7
# 33   183159  97.0
# 34   183161  97.1
# 35   183164  89.4
# 36   183166  97.0
# 37   183169  97.1
# 38   183170  97.1
# 39   183171  97.1
# 40   183172  97.1
# 41   183173  97.0
# 42   183174  97.1
# 43   183176  96.2
# 44   183178  97.1
# 45   183179  97.0
# 46   183180  97.1
# 47   183183  97.7
# 48   183184  97.6
# ...

# %%
df_a_merge = pd.merge(df_a1,df_a4[["userid","rate"]], on = "userid", how = "left")
df_a_merge
# Out:
#      Unnamed: 0  userid  kad_perfectscore_pro  submitnum_kad_ave  \
# 0             0  182233                  0.18               3.62
# 1             1  182324                  0.86               2.23
# 2             2  182669                  0.86               3.20
# 3             3  182771                  0.59               4.33
# 4             4  182787                  0.55               2.40
# 5             5  183117                  1.00               3.00
# 6             6  183119                  0.95               2.23
# 7             7  183120                  0.95               3.45
# 8             8  183123                  1.00               3.18
# 9             9  183125                  0.95               3.32
# 10           10  183126                  0.91               3.09
# 11           11  183127                  0.82               3.68
# 12           12  183128                  0.91               4.18
# ...

# %%
df_a2_merge=df_a_merge.dropna(subset=['rate'])
len(df_a2_merge)
# Out:
# 281

# %%
df_a2_merge.to_csv("saisinnbann_CDEFJKL1819_10_rate.csv")
